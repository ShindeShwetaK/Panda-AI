# %%
# !pip install pandasai
# Out:
# ...
#   Obtaining dependency information for pandasai from https://files.pythonhosted.org/packages/0c/bd/55916f5e3d240033b743737e048fe8b397ca79f9fba27741ace1fadfcee1/pandasai-2.2.14-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for astor<0.9.0,>=0.8.1 from https://files.pythonhosted.org/packages/c3/88/97eef84f48fa04fbd6750e62dcceafba6c63c81b7ac1420856c8dcc0a3f9/astor-0.8.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for duckdb<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/56/f0/02ed53651c9f59940da409fab8ce546120d31bdca722990a5bfbe1f7e8f2/duckdb-1.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for faker<20.0.0,>=19.12.0 from https://files.pythonhosted.org/packages/18/d6/314868f573b09d9f0590a2c2f7dd7463153d3dab1049f0ba5e7008776d91/Faker-19.13.0-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd
from pandasai import Agent
import os

pokemon = pd.read_csv("F:/pokemon.csv")
os.environ["PANDASAI_API_KEY"] = "$2a$10$XTe7iAvy25NPtngicQZn1uoKXyV5lL/uZm1hUAOpAW6gWQOhMpBWa"
#"$2a$10$Ly7yP5HidAEBlHkEe/VBKuLKod53WEOxup16zTtQkwLxoYYMzqlya"

agent = Agent(pokemon)
#agent.chat('What are the columns in pokemon')

# %%
agent.chat('What are the values in Type 1 columns')
# Out:
# 'Grass, Fire, Water, Bug, Normal, Poison, Electric, Ground, Fairy, Fighting, Psychic, Rock, Ghost, Ice, Dragon, Dark, Steel, Flying'

# %%
agent.chat('What are the values in Type2 columns')
# Out:
# 'Unique values in Type 2 column: Poison, nan, Flying, Dragon, Ground, Fairy, Grass, Fighting, Psychic, Steel, Ice, Rock, Dark, Water, Electric, Fire, Ghost, Bug, Normal'

# %%
agent.chat('Plot a graph to show Generation against top 10 pokemon Name')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat('Plot a histogram to show different range Speed of pokemon Name use color red')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat('Plot a line graph to show top 20 attacks done By pokemon use color green, align the x axis properly')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat('Plot a pie chart to show 10 min totals of the pokemon Name with Title "10 Minimum number of pokemon"')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat
('Scatter plot to show the Type1 on y axis of random 10 pokemon name on x axis,on same graph,align the x axis properly')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat('Plot to show the frequenty of Type1 pokemon with color orange')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat('Plot to show the frequenty of Type2 pokemon with color orange')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'

# %%
agent.chat('Plot graph to get the frequency of the Legendary in color in cyan and magenta colors')
# Out:
# 'C:/Users/karti/exports/charts/temp_chart.png'
